# %% [markdown]
# # DASHBOARD FX

# %% [markdown]
# Cargando paqueteria:

# %%
import mysql.connector
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# %% [markdown]
# Cargando la base de datos:

# %%
broker_quotes=pd.read_csv('broker_quotes.csv')
eurbrl=pd.read_csv('eurbrl.csv')
eurmxn=pd.read_csv('eurmxn.csv')
eurusd=pd.read_csv('eurusd.csv')
skewfenics=pd.read_csv('skewfenics.csv')
spots=pd.read_csv('spots.csv')
usd=pd.read_csv('usd.csv')
usdbrl=pd.read_csv('usdbrl.csv')
usdcop=pd.read_csv('usdcop.csv')
usdmxn=pd.read_csv('usdmxn.csv')
usdpen=pd.read_csv('usdpen.csv')

##df es un diccionario de dataframes en pandas.

df = {'eurbrl': eurbrl, 'eurmxn': eurmxn, 'eurusd':eurusd, 'skewfenics':skewfenics, 'spots':spots, 'usd':usd, 'usdbrl':usdbrl, 
      'usdcop': usdcop, 'usdmxn':usdmxn, 'usdpen':usdpen }

# df['eurbrl']

# %%
time=df["eurbrl"]["Fecha"]
EURBRL=df["eurbrl"]["EURBRL Curncy PX_LAST"]

# %%
#plt.scatter(time, EURBRL)
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.lineplot(y=EURBRL, x=time,  palette="tab10", linewidth=.5)

# %%
#######
# Here we'll use the .csv dataset to demonstrate
# how multiple inputs can affect the same graph.
######
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.graph_objs as go
import pandas as pd
# external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

# app = dash.Dash(__name__, external_stylesheets=external_stylesheets)



app = dash.Dash()
df = pd.read_csv("eurbrl.csv")
features = df.columns
app.layout = html.Div([
            
            html.Div([dcc.Dropdown(id='xaxis', options=[{'label': features[0].title(), 'value': features[0]}],value='Fecha' ) ],
                style={'width': '48%', 'display': 'inline-block'}),
            html.Div([ dcc.Dropdown(id='yaxis',options=[{'label': i.title(), 'value': i} for i in features],  value='Fecha' ) ],
                style={'width': '48%', 'float': 'right', 'display': 'inline-block'}),
            dcc.Graph(id='feature-graphic')], style={'padding':1})

@app.callback(
    Output('feature-graphic', 'figure'),
    [Input('xaxis', 'value'), Input('yaxis', 'value')])
def update_graph(xaxis_name, yaxis_name):
    return {
            'data': [go.Scatter(
                x=df[xaxis_name],
                y=df[yaxis_name],
                text="",
                mode='lines',
                marker={
                    'size': 15,
                    'opacity': 0.5,
                    'line': {'width': 0.5, 'color': 'white'}
                }
            )],
            'layout': go.Layout(
                xaxis={'title': xaxis_name.title()},
                yaxis={'title': yaxis_name.title()},
                margin={'l': 40, 'b': 40, 't': 10, 'r': 0},
                hovermode='closest'
            )
        }

if __name__ == '__main__':
    app.run_server(debug ='True' ,port=8080,host='127.0.0.1')
# Out:
# Running on http://127.0.0.1:8080/
# Running on http://127.0.0.1:8080/
# Running on http://127.0.0.1:8080/
# Running on http://127.0.0.1:8080/
# Running on http://127.0.0.1:8080/
# Running on http://127.0.0.1:8080/
# Running on http://127.0.0.1:8080/
# Running on http://127.0.0.1:8080/
# Running on http://127.0.0.1:8080/
# Running on http://127.0.0.1:8080/
# Running on http://127.0.0.1:8080/
# Running on http://127.0.0.1:8080/
# Running on http://127.0.0.1:8080/
# Running on http://127.0.0.1:8080/
# Running on http://127.0.0.1:8080/
# Running on http://127.0.0.1:8080/
# Running on http://127.0.0.1:8080/
# Running on http://127.0.0.1:8080/
# Running on http://127.0.0.1:8080/
# Running on http://127.0.0.1:8080/
# Running on http://127.0.0.1:8080/
# Running on http://127.0.0.1:8080/
# Running on http://127.0.0.1:8080/
# Running on http://127.0.0.1:8080/
# Running on http://127.0.0.1:8080/
# Running on http://127.0.0.1:8080/
# Running on http://127.0.0.1:8080/
# ...

# %%
#######
# Here we'll use the .csv dataset to demonstrate
# how multiple inputs can affect the same graph.
######
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.graph_objs as go
import pandas as pd
# external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

# app = dash.Dash(__name__, external_stylesheets=external_stylesheets)

broker_quotes=pd.read_csv('broker_quotes.csv')
eurbrl=pd.read_csv('eurbrl.csv')
eurmxn=pd.read_csv('eurmxn.csv')
eurusd=pd.read_csv('eurusd.csv')
skewfenics=pd.read_csv('skewfenics.csv')
spots=pd.read_csv('spots.csv')
usd=pd.read_csv('usd.csv')
usdbrl=pd.read_csv('usdbrl.csv')
usdcop=pd.read_csv('usdcop.csv')
usdmxn=pd.read_csv('usdmxn.csv')
usdpen=pd.read_csv('usdpen.csv')


a= ["broker_quotes","eurbrl","eurmxn","eurusd","skewfenics","spots","usd","usdbrl","usdcop","usdmxn","usdpen"]




app = dash.Dash()
df = pd.read_csv("eurbrl.csv")
features = df.columns




app.layout =html.Div([
            
            html.Div(dcc.Dropdown(id='base',options=[{'label': i, 'value': i} for i in a],value='MTL')),   
            html.Div([dcc.Dropdown(id='xaxis', options=[{'label': features[0].title(), 'value': features[0]}],value='Fecha' ) ],
                style={'width': '48%', 'display': 'inline-block'}),
            html.Div([ dcc.Dropdown(id='yaxis',options=[{'label': i.title(), 'value': i} for i in features],  value='Fecha' ) ],
                style={'width': '48%', 'float': 'right', 'display': 'inline-block'}),
            dcc.Graph(id='feature-graphic')], style={'padding':1})

@app.callback(
    Output('feature-graphic', 'figure'),
    [Input('xaxis', 'value'), Input('yaxis', 'value')])
def update_graph(xaxis_name, yaxis_name):
    return {
            'data': [go.Scatter(
                x=df[xaxis_name],
                y=df[yaxis_name],
                text="",
                mode='lines',
                marker={
                    'size': 15,
                    'opacity': 0.5,
                    'line': {'width': 0.5, 'color': 'white'}
                }
            )],
            'layout': go.Layout(
                xaxis={'title': xaxis_name.title()},
                yaxis={'title': yaxis_name.title()},
                margin={'l': 40, 'b': 40, 't': 10, 'r': 0},
                hovermode='closest'
            )
        }

if __name__ == '__main__':
    app.run_server()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [03/Apr/2019 16:23:42] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Apr/2019 16:23:42] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Apr/2019 16:23:42] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Apr/2019 16:23:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Apr/2019 16:23:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Apr/2019 16:23:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Apr/2019 16:23:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Apr/2019 16:23:58] "POST /_dash-update-component HTTP/1.1" 200 -

# %%
a= ["broker_quotes","eurbrl","eurmxn","eurusd","skewfenics","spots","usd","usdbrl","usdcop","usdmxn","usdpen"]

# %%
a
# Out:
# ['broker_quotes',
#  'eurbrl',
#  'eurmxn',
#  'eurusd',
#  'skewfenics',
#  'spots',
#  'usd',
#  'usdbrl',
#  'usdcop',
#  'usdmxn',
#  'usdpen']

# %%
import dash
import flask
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.graph_objs as go
import pandas as pd
server = flask.Flask(__name__)
app = dash.Dash(__name__, server=server)

app.layout = html.Div(
    children=[
            "stuff goes here"
    ]
)

if __name__ == '__main__':
    app.run_server(debug=True, port=8050, host='127.0.0.1')
    app.run_server(debug=True)
# Out:
# Running on http://127.0.0.1:8050/
# Running on http://127.0.0.1:8050/
# Debugger PIN: 748-873-863
# Debugger PIN: 748-873-863
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: on
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3275: UserWarning:
#
# To exit: use 'exit', 'quit', or Ctrl-D.
